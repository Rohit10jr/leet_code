# %% [markdown]
# **108. Convert Sorted Array to Binary Search Tree**
#
# Given an integer array nums where the elements are sorted in ascending order, convert it to a height-balanced binary search tree.
#
#
# Example 1:
#
#     Input: nums = [-10,-3,0,5,9]
#     Output: [0,-3,9,-10,null,5]
#     Explanation: [0,-10,5,null,-3,null,9] is also accepted:
#
# Example 2:
#
#     Input: nums = [1,3]
#     Output: [3,1]
#     Explanation: [1,null,3] and [3,1] are both height-balanced BSTs.

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right
        print(f"TreeNode val: {self.val}, left: {self.left}, right: {self.right}")

class Solution:
    def sortedArrayToBST(self, nums):
        """
        :type nums: List[int]
        :rtype: Optional[TreeNode]
        """
        # Base case: empty array
        if not nums:
            return None

        # Pick the middle element as the root
        mid = len(nums) // 2
        root = TreeNode(nums[mid])
        print(f"mid: {mid}, root: {nums[mid]}")

        # Recursively build left and right subtrees
        print(f"root.left: {nums[:mid]} \n")
        root.left = self.sortedArrayToBST(nums[:mid])
        print(f"root.right: {nums[mid+1:]} \n")
        root.right = self.sortedArrayToBST(nums[mid+1:])

        return root

# %%
def print_tree(root, level=0, prefix="Root:"):
    if root is not None:
        print("   " * level + f"{prefix} {root.val}")
        print_tree(root.left, level + 1, "L---")
        print_tree(root.right, level + 1, "R---")

# Example usage:
nums = [-10, -3, 0, 5, 9]
sol = Solution()
bst_root = sol.sortedArrayToBST(nums)

print("Height-balanced BST from sorted array:")
print_tree(bst_root)
# Out:
# TreeNode val: 0, left: None, right: None
# mid: 2, root: 0
# root.left: [-10, -3]
#
# TreeNode val: -3, left: None, right: None
# mid: 1, root: -3
# root.left: [-10]
#
# TreeNode val: -10, left: None, right: None
# mid: 0, root: -10
# root.left: []
#
# root.right: []
#
# root.right: []
#
# root.right: [5, 9]
#
# TreeNode val: 9, left: None, right: None
# mid: 1, root: 9
# root.left: [5]
#
# TreeNode val: 5, left: None, right: None
# mid: 0, root: 5
# root.left: []
#
# root.right: []
#
# root.right: []
#
# Height-balanced BST from sorted array:
# Root: 0
#    L--- -3
#       L--- -10
#    R--- 9
#       L--- 5

# %%
nums = [-10, -3, 0, 5, 9]
mid = len(nums) // 2
mid1 = 1 // 2
mid2 = 2 // 2
mid3 = 3 // 2
print(f"mid: {mid}, mid1: {mid1}, mid2: {mid2}, mid3: {mid3}")
print("Left sort", (nums[:mid]))
print("Left sort", (nums[:0]))
print("Right sort", (nums[mid+1:]))

num2 = [-10, -3]
print(num2[2:])
num3 = [0, 5, 9]
print(num3[1+1:])

num4 = [5, 9]
print(num4[:1])
print(num4[1+1:])
# Out:
# mid: 2, mid1: 0, mid2: 1, mid3: 1
# Left sort [-10, -3]
# Left sort []
# Right sort [5, 9]
# []
# [9]
# [5]
# []
