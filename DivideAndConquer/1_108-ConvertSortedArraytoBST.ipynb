# %% [markdown]
# **108. Convert Sorted Array to Binary Search Tree**
#
# Given an integer array nums where the elements are sorted in ascending order, convert it to a height-balanced binary search tree.
#
#
# Example 1:
#
#     Input: nums = [-10,-3,0,5,9]
#     Output: [0,-3,9,-10,null,5]
#     Explanation: [0,-10,5,null,-3,null,9] is also accepted:
#
# Example 2:
#
#     Input: nums = [1,3]
#     Output: [3,1]
#     Explanation: [1,null,3] and [3,1] are both height-balanced BSTs.

# %%
# Definition for a binary tree node.
class TreeNode(object):
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution(object):
    def sortedArrayToBST(self, nums):
        """
        :type nums: List[int]
        :rtype: Optional[TreeNode]
        """
        # Base case: empty array
        if not nums:
            return None

        # Pick the middle element as the root
        mid = len(nums) // 2
        root = TreeNode(nums[mid])
        print("------")
        print(f"mid: {mid}, root:{root}")

        # Recursively build left and right subtrees
        root.left = self.sortedArrayToBST(nums[:mid])
        print(root.left)
        root.right = self.sortedArrayToBST(nums[mid+1:])
        print(root.right)

        return root

# %%
def print_tree(root, level=0, prefix="Root:"):
    if root is not None:
        print("   " * level + f"{prefix} {root.val}")
        print_tree(root.left, level + 1, "L---")
        print_tree(root.right, level + 1, "R---")

# Example usage:
nums = [-10, -3, 0, 5, 9]
sol = Solution()
bst_root = sol.sortedArrayToBST(nums)

print("Height-balanced BST from sorted array:")
print_tree(bst_root)
# Out:
# ------
# mid: 2, root:<__main__.TreeNode object at 0x0000026A3CD128D0>
# ------
# mid: 1, root:<__main__.TreeNode object at 0x0000026A3C743910>
# ------
# mid: 0, root:<__main__.TreeNode object at 0x0000026A3CD33810>
# None
# None
# <__main__.TreeNode object at 0x0000026A3CD33810>
# None
# <__main__.TreeNode object at 0x0000026A3C743910>
# ------
# mid: 1, root:<__main__.TreeNode object at 0x0000026A3CD31750>
# ------
# mid: 0, root:<__main__.TreeNode object at 0x0000026A3CD33D90>
# None
# None
# <__main__.TreeNode object at 0x0000026A3CD33D90>
# None
# <__main__.TreeNode object at 0x0000026A3CD31750>
# Height-balanced BST from sorted array:
# Root: 0
#    L--- -3
#       L--- -10
#    R--- 9
#       L--- 5

# %%
nums = [-10, -3, 0, 5, 9]
mid = len(nums) // 2
print(f"mid: {mid}")
print("Left sort", (nums[:mid]))
print("Right sort", (nums[mid+1:]))
# Out:
# mid: 2
# Left sort [-10, -3]
# Right sort [5, 9]
