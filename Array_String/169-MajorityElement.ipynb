# %% [markdown]
# **169. Majority Element**
#
# Given an array nums of size n, return the majority element.
#
# The majority element is the element that appears more than ⌊n / 2⌋ times. You may assume that the majority element always exists in the array.
#
# Example 1:
#
# Input: nums = [3,2,3]
# Output: 3
#
# Example 2:
#
# Input: nums = [2,2,1,1,1,2,2]
# Output: 2

# %%
from collections import Counter
 
class Solution:
    def majorityElement(self, nums):
        """
        :type nums: List[int]
        :rtype: int
        """
        '''mine'''
        counts = Counter(nums)
        max_count = max(counts, key=counts.get)
        return max_count


nums = [3, 3, 2, 2, 2, 2, 2, 4, 4]
s = Solution()
s.majorityElement(nums)

# %%
'''Boyer-Moore Python Code:'''
def majorityElement(nums):
    count = 0
    candidate = None

    for num in nums:
        if count == 0:
            candidate = num
        count += (1 if num == candidate else -1)

    return candidate

nums = [3, 3, 2, 2, 2, 2, 2, 4, 4]
print("Majority Element:", majorityElement(nums))   


# '''sorting''' 
# def majorityElement(nums):
#     nums.sort()
#     print(nums)
#     print(len(nums))
#     print(len(nums)//2)
#     return nums[len(nums) // 2]
#     # print(final_result)
    

# nums = [3, 3, 2, 2, 2, 2, 2, 4, 4]
# print("Majority Element:", majorityElement(nums))   

# '''Hash Map'''
# from collections import defaultdict
# def majorityElement(nums):
#     counts = defaultdict(int)
#     for num in nums:
#         counts[num] += 1
#     return max(counts, key=counts.get)

# nums = [3, 3, 4, 2, 4, 4, 2, 4, 4]
# print("Majority Element:", majorityElement(nums))


# '''Randomization'''
# import random
# def majorityElement(nums):
#     while True:
#         candidate = random.choice(nums)-
#         if nums.count(candidate) > len(nums) // 2:
#             return candidate
            
# nums = [3, 3, 4, 2, 4, 4, 2, 4, 4]
# print("Majority Element:", majorityElement(nums))

# '''Divide and Conquer'''
# def majorityElement(nums):
#     def majority_element_recursive(left, right):
#         # Base case: If the subarray contains only one element, it is the majority element
#         if left == right:
#             return nums[left]

#         # Divide the array into two halves
#         mid = (left + right) // 2

#         # Recursively find the majority elements in the two halves
#         left_majority = majority_element_recursive(left, mid)
#         right_majority = majority_element_recursive(mid + 1, right)

#         # If both halves have the same majority element, return it
#         if left_majority == right_majority:
#             return left_majority

#         # Otherwise, count the occurrences of both elements in the entire array
#         left_count = sum(1 for i in range(left, right + 1) if nums[i] == left_majority)
#         right_count = sum(1 for i in range(left, right + 1) if nums[i] == right_majority)

#         # Return the majority element with more occurrences
#         return left_majority if left_count > right_count else right_majority

#     return majority_element_recursive(0, len(nums) - 1)

# nums = [3, 3, 4, 2, 4, 4, 2, 4, 4]
# print("Majority Element:", majorityElement(nums))
# Out:
# Majority Element: 2
