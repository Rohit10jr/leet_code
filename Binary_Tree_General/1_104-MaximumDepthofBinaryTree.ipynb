# %% [markdown]
# 104. Maximum Depth of Binary Tree
#
#
# Given the root of a binary tree, return its maximum depth.
# A binary tree's maximum depth is the number of nodes along the longest path
# from the root node down to the farthest leaf node.
#
# Example 1:
#
#     Input: root = [3,9,20,null,null,15,7]
#     Output: 3
#
# Example 2:
#
#     Input: root = [1,null,2]
#     Output: 2

# %%
# Definition for a binary tree node.
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

class Solution:
    def maxDepth(self, root: TreeNode) -> int:
        # Base case: If the root is null, the depth is 0.
        if root is None:
            return 0
        
        # Recursively calculate the maximum depth of the left subtree.
        left_depth = self.maxDepth(root.left)
        
        # Recursively calculate the maximum depth of the right subtree.
        right_depth = self.maxDepth(root.right)
        
        # The maximum depth for the current node is 1 (for the current node itself)
        # plus the maximum of the depths of its left and right subtrees.
        return 1 + max(left_depth, right_depth)

# %% [markdown]
# ### 🔁 Summary of Call Stack
#
# ```
# maxDepth(0)
# ├── maxDepth(9) → 1
# └── maxDepth(20)
#     ├── maxDepth(15) → 1
#     └── maxDepth(7) → 1
#     → returns 2
#
# maxDepth(0) → 1 + max(1, 2) = 3
# ```

# %%
root = TreeNode()
root.left = TreeNode(9)
root.right = TreeNode(20)
root.right.left = TreeNode(15)
root.right.right = TreeNode(7)

def print_tree(node, level=0, side="root"):
    if node:
        indent = "   " * level
        print(f"{indent}- {side}: {node.val}")
        print_tree(node.left, level + 1, "L")
        print_tree(node.right, level + 1, "R")

# Print Tree
print_tree(root)

solution = Solution()
depth = solution.maxDepth(root)
print("Maximum Depth of the Tree: ", depth)
# Out:
# - root: 0
#    - L: 9
#    - R: 20
#       - L: 15
#       - R: 7
# Maximum Depth of the Tree:  3

# %%
# Example for recursions
def factorial(n):
    if n == 0:
        return 1
    return n * factorial(n - 1)

factorial(3)
# => 3 * factorial(2)
# => 3 * (2 * factorial(1))
# => 3 * (2 * (1 * factorial(0)))
# => 3 * 2 * 1 * 1
# => 6

#  --- just example ---

# i = 1
# def factorial2(n=0):
#     global i
#     print("i", i)
#     if n == 0:
#         return 1
#     i += 1
#     return n * factorial2(n - 1)

def factorial3(n, i=1):
    print("i", i)
    if n == 0:
        return 1
    return n * factorial3(n - 1, i + 1)

n = 3
print(factorial3(n))
# Out:
# 6
