# %% [markdown]
# **9. Palindrome Number**
#
# Given an integer x, return true if x is a palindrome, and false otherwise.
#
# Example 1:
#
#     Input: x = 121
#     Output: true
#
# Explanation: 121 reads as 121 from left to right and from right to left.
#
# Example 2:
#
#     Input: x = -121
#     Output: false
#
# Explanation: From left to right, it reads -121. From right to left, it becomes 121-. Therefore it is not a palindrome.

# %%
class Solution:    
    def isPalindrome(self, x: int) -> bool:
        # Negative numbers and Numbers ending with 0 are not palindromes, 0 is palindrome
        if x < 0 or (x % 10 == 0 and x != 0):
            return False

        revertedNumber = 0
        while x > revertedNumber:
            revertedNumber = revertedNumber * 10 + x % 10
            x //= 10

        # When the length is an odd number, we can get rid of the middle digit by revertedNumber // 10 and compare.
        # example, input = 121, at the end of while loop, x = 1, and revertedNumber = 12.
        return x == revertedNumber or x == revertedNumber // 10

# %%
class Solution2:
    def palindrome(self, x):
        if x < 0:
            return False
        s = str(x)
        return s == s[::-1]

# %%
print(121%10)
print(121//10)
r=0
print((r*10) + (1221%10))
# Out:
# 1
# 12
# 1

# %%
sol  = Solution()

# Example Usage:
print(f"Is 121 a palindrome? {sol.isPalindrome(121)}")
print(f"Is -121 a palindrome? {sol.isPalindrome(-121)}")
print(f"Is 10 a palindrome? {sol.isPalindrome(10)}")
print(f"Is 0 a palindrome? {sol.isPalindrome(0)}")
print(f"Is 12345 a palindrome? {sol.isPalindrome(12345)}")
# Out:
# Is 121 a palindrome? True
# Is -121 a palindrome? False
# Is 10 a palindrome? False
# Is 0 a palindrome? True
# Is 12345 a palindrome? False

# %%
# divide, floor divide, ceilling divide, modulus
import math

a=10
b=5
c=6

print("a / b =", a / b)   # Division: returns the exact quotient as a float (10 / 5 = 2.0)

# Floor division (//) returns equal to the division result or rounds down to nearest integer (the floor, towards negative infinity).
print("a // b =", a // b)  # Example: 10 // 5 = 2 (since 10/5=2.0, floor is 2)
print("a // c =", a // c)  # Example: 10 // 6 = 1 (since 10/6≈1.666..., floor is 1)

# The opposite of floor division is "ceiling division," which rounds up to the nearest integer (towards positive infinity).
result = math.ceil(a / b)
print("math.ceil(a / b) =", result)

print("a % b =", a % b)   # Modulus: returns the remainder after division (10 % 5 = 0)
# Out:
# a / b = 2.0
# a // b = 2
# a // c = 1
# math.ceil(a / b) = 2
# a % b = 0
