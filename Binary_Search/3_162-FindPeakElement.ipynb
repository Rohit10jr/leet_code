# %% [markdown]
# **162. Find Peak Element**
#
# A peak element is an element that is strictly greater than its neighbors.
#
# Given a 0-indexed integer array nums, find a peak element, and return its index. If the array contains multiple peaks, return the index to any of the peaks.
#
# You may imagine that nums[-1] = nums[n] = -∞. In other words, an element is always considered to be strictly greater than a neighbor that is outside the array.
#
# You must write an algorithm that runs in O(log n) time.
#
#
#
# Example 1:
#
#     Input: nums = [1,2,3,1]
#     Output: 2
#
# Explanation: 3 is a peak element and your function should return the index number 2.
#
# Example 2:
#
#     Input: nums = [1,2,1,3,5,6,4]
#     Output: 5
#
# Explanation: Your function can return either index number 1 where the peak element is 2, or index number 5 where the peak element is 6.
#
#
# Constraints:
#
# - 1 <= nums.length <= 1000
# - -231 <= nums[i] <= 231 - 1
# - nums[i] != nums[i + 1] for all valid i.

# %%
class Solution:
    def findPeakElement(self, nums: list[int]) -> int:
        n = len(nums)
        if n == 1:
            return 0  # A single element array always has its element as a peak

        low = 0
        high = n - 1
        print("="*10, "outside loop", "="*10)
        print(" low =", low, "high =", high)
        i = 0
        while low < high:
            mid = low + (high - low) // 2

            # Compare mid element with its right neighbor
            if nums[mid] < nums[mid + 1]:
                # It's a increasing slope. A peak must be to the right.
                low = mid + 1
            else: # nums[mid] > nums[mid + 1]:
                # It's a decreasing slope or at a peak. A peak must be at or to the left of mid.
                high = mid
            i=i+1
            print(f"--- inside while loop, iteration {i}---")
            print(f"mid {mid} low {low} high {high}")

        # When low == high, we have found a peak element
        return low

# %%
# Example Usage:
solution = Solution()

print("Example 1")
nums1 = [1,2,3,1]
print(f"Input: {nums1}, Peak index: {solution.findPeakElement(nums1)}") # Expected: 2

print("\nExample 2")
nums2 = [1,2,1,3,5,6,4]
print(f"Input: {nums2}, Peak index: {solution.findPeakElement(nums2)}") # Expected: 5 (or 1)

print("\nExample 3 strictly increasing")
nums3 = [1,2,3,4,5]
print(f"Input: {nums3}, Peak index: {solution.findPeakElement(nums3)}") # Expected: 4

print("\nExample 4 strictly decreasing")
nums4 = [5,4,3,2,1]
print(f"Input: {nums4}, Peak index: {solution.findPeakElement(nums4)}") # Expected: 0

print("\nExample 5 two peaks")
nums5 = [1,6,2,7,3]
print(f"Input: {nums5}, Peak index: {solution.findPeakElement(nums5)}") # Expected: 1 or 3

print("\nExample 6 single element")
nums6 = [7]
print(f"Input: {nums6}, Peak index: {solution.findPeakElement(nums6)}") # Expected: 0s
# Out:
# Example 1
# ========== outside loop ==========
#  low = 0 high = 3
# --- inside while loop, iteration 1---
# mid 1 low 2 high 3
# --- inside while loop, iteration 2---
# mid 2 low 2 high 2
# Input: [1, 2, 3, 1], Peak index: 2
#
# Example 2
# ========== outside loop ==========
#  low = 0 high = 6
# --- inside while loop, iteration 1---
# mid 3 low 4 high 6
# --- inside while loop, iteration 2---
# mid 5 low 4 high 5
# --- inside while loop, iteration 3---
# mid 4 low 5 high 5
# Input: [1, 2, 1, 3, 5, 6, 4], Peak index: 5
#
# Example 3 strictly increasing
# ========== outside loop ==========
#  low = 0 high = 4
# --- inside while loop, iteration 1---
# mid 2 low 3 high 4
# --- inside while loop, iteration 2---
# mid 3 low 4 high 4
# Input: [1, 2, 3, 4, 5], Peak index: 4
#
# Example 4 strictly decreasing
# ========== outside loop ==========
#  low = 0 high = 4
# --- inside while loop, iteration 1---
# mid 2 low 0 high 2
# --- inside while loop, iteration 2---
# mid 1 low 0 high 1
# ...
