# %% [markdown]
# **74. Search a 2D Matrix**
#
# You are given an m x n integer matrix matrix with the following two properties:
#
# Each row is sorted in non-decreasing order.
# The first integer of each row is greater than the last integer of the previous row.
# Given an integer target, return true if target is in matrix or false otherwise.
#
# You must write a solution in O(log(m * n)) time complexity.
#
# Example 1:
#
#     Input: matrix = [[1,3,5,7],[10,11,16,20],[23,30,34,60]], target = 3
#     Output: true
#
# Example 2:
#
#     Input: matrix = [[1,3,5,7],[10,11,16,20],[23,30,34,60]], target = 13
#     Output: false

# %%
class Solution:
    def searchMatrix(self, matrix: list[list[int]], target: int) -> bool:
        m = len(matrix)
        if m == 0:
            return False
        n = len(matrix[0])
        if n == 0:
            return False

        low = 0
        high = (m * n) - 1

        while low <= high:
            mid = low + (high - low) // 2

            # Convert 1D mid index to 2D coordinates
            row = mid // n
            col = mid % n

            current_element = matrix[row][col]

            if current_element == target:
                return True
            elif current_element < target:
                low = mid + 1
            else:  # current_element > target
                high = mid - 1

        return False

# %%
# Example Usage:
solution = Solution()

# Example 1
matrix1 = [[1,3,5,7],[10,11,16,20],[23,30,34,60]]
target1 = 3
print(f"Matrix: {matrix1}, Target: {target1}, Found: {solution.searchMatrix(matrix1, target1)}") # Expected: True

# Example 2 (Target not found)
matrix2 = [[1,3,5,7],[10,11,16,20],[23,30,34,60]]
target2 = 13
print(f"Matrix: {matrix2}, Target: {target2}, Found: {solution.searchMatrix(matrix2, target2)}") # Expected: False

# Example 3 (Single element matrix - target found)
matrix3 = [[5]]
target3 = 5
print(f"Matrix: {matrix3}, Target: {target3}, Found: {solution.searchMatrix(matrix3, target3)}") # Expected: True

# Example 4 (Empty matrix)
matrix5 = []
target5 = 10
print(f"Matrix: {matrix5}, Target: {target5}, Found: {solution.searchMatrix(matrix5, target5)}") # Expected: False

# Example 5 (Matrix with empty rows)
matrix6 = [[]]
target6 = 10
print(f"Matrix: {matrix6}, Target: {target6}, Found: {solution.searchMatrix(matrix6, target6)}") # Expected: False
# Out:
# Matrix: [[1, 3, 5, 7], [10, 11, 16, 20], [23, 30, 34, 60]], Target: 3, Found: True
# Matrix: [[1, 3, 5, 7], [10, 11, 16, 20], [23, 30, 34, 60]], Target: 13, Found: False
# Matrix: [[5]], Target: 5, Found: True
# Matrix: [], Target: 10, Found: False
# Matrix: [[]], Target: 10, Found: False

# %%
0//4
# 0%4
# Out:
# 0
