# %% [markdown]
# **322. Coin Change**
#
# You are given an integer array coins representing coins of different denominations and an integer amount representing a total amount of money.
#
# Return the fewest number of coins that you need to make up that amount. If that amount of money cannot be made up by any combination of the coins, return -1.
#
# You may assume that you have an infinite number of each kind of coin.
#
#
# Example 1:
#
#     Input: coins = [1,2,5], amount = 11
#     Output: 3
#     Explanation: 11 = 5 + 5 + 1
#
# Example 2:
#
#     Input: coins = [2], amount = 3
#     Output: -1
#
# Example 3:
#
#     Input: coins = [1], amount = 0
#     Output: 0

# %%
class Solution(object):
    def coinChange(self, coins, amount):
        """
        :type coins: List[int]
        :type amount: int
        :rtype: int
        """
        # Initialize dp array
        dp = [float('inf')] * (amount + 1)
        dp[0] = 0   # 0 coins needed to make amount 0

        print("amount =", amount)
        print("coins =", coins)
        print("----------------------")

        for coin in coins:
            print("dp =", dp)
            print(f"range({coin}, {amount} + 1)")
            print(" ")
            # Update dp for each possible amount >= coin
            for i in range(coin, amount + 1):
                print("coin =", coin, "i =", i)
                print("dp[i] =", dp[i])
                print("dp[i - coin] + 1 =", dp[i - coin] + 1)
                print("----------------------")
                dp[i] = min(dp[i], dp[i - coin] + 1)

        # If dp[amount] is still infinity → cannot form that amount
        print("outside loop")
        print("dp =", dp)
        return dp[amount] if dp[amount] != float('inf') else -1

# %%
# coins = [1,2,5]
# amount = 11

coins = [1,2,5]
amount = 6

sol = Solution()
print(sol.coinChange(coins, amount))
# Out:
# amount = 6
# coins = [1, 2, 5]
# ----------------------
# dp = [0, inf, inf, inf, inf, inf, inf]
# range(1, 6 + 1)
#
# coin = 1 i = 1
# dp[i] = inf
# dp[i - coin] + 1 = 1
# ----------------------
# coin = 1 i = 2
# dp[i] = inf
# dp[i - coin] + 1 = 2
# ----------------------
# coin = 1 i = 3
# dp[i] = inf
# dp[i - coin] + 1 = 3
# ----------------------
# coin = 1 i = 4
# dp[i] = inf
# dp[i - coin] + 1 = 4
# ----------------------
# coin = 1 i = 5
# dp[i] = inf
# dp[i - coin] + 1 = 5
# ----------------------
# coin = 1 i = 6
# dp[i] = inf
# dp[i - coin] + 1 = 6
# ----------------------
# dp = [0, 1, 2, 3, 4, 5, 6]
# range(2, 6 + 1)
#
# coin = 2 i = 2
# dp[i] = 2
# dp[i - coin] + 1 = 1
# ----------------------
# coin = 2 i = 3
# dp[i] = 3
# dp[i - coin] + 1 = 2
# ----------------------
# coin = 2 i = 4
# dp[i] = 4
# dp[i - coin] + 1 = 2
# ----------------------
# coin = 2 i = 5
# dp[i] = 5
# dp[i - coin] + 1 = 3
# ----------------------
# coin = 2 i = 6
# dp[i] = 6
# dp[i - coin] + 1 = 3
# ----------------------
# dp = [0, 1, 1, 2, 2, 3, 3]
# range(5, 6 + 1)
#
# coin = 5 i = 5
# dp[i] = 3
# dp[i - coin] + 1 = 1
# ----------------------
# coin = 5 i = 6
# dp[i] = 3
# dp[i - coin] + 1 = 2
# ----------------------
# outside loop
# dp = [0, 1, 1, 2, 2, 1, 2]
# 2

# %%
dp = [float('inf')] * (5 + 1)
print(dp)

n = float('inf')
print(n-1)
# Out:
# [inf, inf, inf, inf, inf, inf]
# inf
