# %% [markdown]
# **14. Longest Common Prefix**
#
# Write a function to find the longest common prefix string amongst an array of strings.
#
# If there is no common prefix, return an empty string "".
#
#
# Example 1:
#
# Input: strs = ["flower","flow","flight"]
# Output: "fl"
# Example 2:
#
# Input: strs = ["dog","racecar","car"]
# Output: ""
# Explanation: There is no common prefix among the input strings.

# %%
class Solution:
    def longestCommonPrefix(self, strs):
        """
        :type strs: List[str]
        :rtype: str
        """
        if not strs:
            return ""
        
        prefix = strs[0]
        for string in strs[1:]:
            while string[:len(prefix)] != prefix:
                prefix = prefix[:-1]
                if not prefix:
                    return ""
        return prefix

        ''' Using Zip and Set '''

        # def longestCommonPrefix2(strs):
        #     if not strs:
        #         return ""
            
        #     min_length = min(len(s) for s in strs)
        #     for i in range(min_length):
        #         if len(set(s[i] for s in strs)) > 1:
        #             return strs[0][:i]
        #     return strs[0][:min_length]

        # # Example usage:
        # strs = ["flower", "flow", "flight"]
        # print(longestCommonPrefix2(strs))  # Output: "fl"

        ''' Sorting and Comparing '''

        # def longestCommonPrefix3(strs):
        #     if not strs:
        #         return ""
            
        #     # Sorting the list of strings
        #     strs.sort()
        #     # Taking the first and last string after sorting
        #     first = strs[0]
        #     last = strs[-1]
        #     prefix = ""
        #     for i in range(len(first)):
        #         if first[i] == last[i]:
        #             # Add this character to the prefix
        #             prefix += first[i]
        #         else:
        #             # If characters are different, then we've found the longest common prefix
        #             break
        #     return prefix

        # strs = ["flower", "flow", "flight"]
        # print(longestCommonPrefix3(strs))  # Output: "fl"

    ''' mine '''

    # def longest_common_prefix6(strs):
    #     if not strs:
    #         return ""
        
    #     # Sort the array of strings to ensure that the shortest string is at the beginning
    #     strs.sort()
    #     print("after sort", strs)
    #     print("length sort", len(strs))
    #     # Take the first string as the potential common prefix
    #     prefix = strs[0]
    #     print("prefix",prefix)
    #     print("length prefix", len(prefix))
    #     print("below inside loop")
    #     last_strs = strs[-1]
    #     print("last_strs",last_strs)
    #     j=0
    #     while j < len(prefix) and j < len(last_strs) and prefix[j] == last_strs[j]:
    #             # 
    #             j += 1
    #     prefix = prefix[:j]
    #     return prefix
    

    # strs = ["flower", "flies", "flight"]
    # print(longest_common_prefix6(strs))

s = Solution()
s.longestCommonPrefix(["flower","flow","flight"])
# Out:
# 'fl'
