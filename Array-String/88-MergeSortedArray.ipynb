# %% [markdown]
# **88. Merge Sorted Array**
#
# You are given two integer arrays nums1 and nums2, sorted in non-decreasing order, and two integers m and n, representing the number of elements in nums1 and nums2 respectively.
#
# Merge nums1 and nums2 into a single array sorted in non-decreasing order.
#
# The final sorted array should not be returned by the function, but instead be stored inside the array nums1. To accommodate this, nums1 has a length of m + n, where the first m elements denote the elements that should be merged, and the last n elements are set to 0 and should be ignored. nums2 has a length of n.
#
#
#
# Example 1:
#
# Input: nums1 = [1,2,3,0,0,0], m = 3, nums2 = [2,5,6], n = 3
# Output: [1,2,2,3,5,6]
# Explanation: The arrays we are merging are [1,2,3] and [2,5,6].
# The result of the merge is [1,2,2,3,5,6] with the underlined elements coming from nums1.

# %% [markdown]
# Approach 1: Two Pointers (From the End) — Optimal
#
# -  Time Complexity: O(m + n)
# -  Space Complexity: O(1) (in-place)

# %%
class Solution:
    def merge(self, nums1, m, nums2, n):
        p1, p2, p = m - 1, n - 1, m + n - 1

        print(f"Initial nums1, m, nums2, n: {nums1}, {m}, {nums2}, {n}")
        print(f"Initial values of p1, p2, p: {p1}, {p2}, {p}")
        print("Starting merge...\n")

        while p1 >= 0 and p2 >= 0:
            print(f"Comparing nums1[{p1}]={nums1[p1]} and nums2[{p2}]={nums2[p2]}")
            if nums1[p1] > nums2[p2]:
                nums1[p] = nums1[p1]
                print(f"Placing nums1[{p1}] at nums1[{p}]")
                p1 -= 1
            else:
                nums1[p] = nums2[p2]
                print(f"Placing nums2[{p2}] at nums1[{p}]")
                p2 -= 1
            p -= 1
            print(f"nums1 now: {nums1}\n")

        # If any elements are left in nums2
        while p2 >= 0:
            print(f"Copying remaining nums2[{p2}]={nums2[p2]} to nums1[{p}]")
            nums1[p] = nums2[p2]
            p2 -= 1
            p -= 1
            print(f"nums1 now: {nums1}\n")

        print("Merge complete.")
        print(f"Final nums1: {nums1}")


nums1=[1, 2, 3, 0, 0, 0]
m=3
nums2=[2, 5, 6]
n=3

s = Solution()
s.merge(nums1, m, nums2, n)
# Out:
# Initial nums1, m, nums2, n: [1, 2, 3, 0, 0, 0], 3, [2, 5, 6], 3
# Initial values of p1, p2, p: 2, 2, 5
# Starting merge...
#
# Comparing nums1[2]=3 and nums2[2]=6
# Placing nums2[2] at nums1[5]
# nums1 now: [1, 2, 3, 0, 0, 6]
#
# Comparing nums1[2]=3 and nums2[1]=5
# Placing nums2[1] at nums1[4]
# nums1 now: [1, 2, 3, 0, 5, 6]
#
# Comparing nums1[2]=3 and nums2[0]=2
# Placing nums1[2] at nums1[3]
# nums1 now: [1, 2, 3, 3, 5, 6]
#
# Copying remaining nums2[0]=2 to nums1[2]
# nums1 now: [1, 2, 2, 3, 5, 6]
#
# Merge complete.
# Final nums1: [1, 2, 2, 3, 5, 6]

# %% [markdown]
# Approach 2: Merge and Sort — Simple but Less Efficient
# - Time Complexity: O((m + n) log(m + n))
# - Space Complexity: O(1) (sort is in-place, but not optimal)

# %%
class Solution:
    def merge(self, nums1, m, nums2, n):
        nums1[m:] = nums2
        nums1.sort()
        print("Merged nums1:", nums1)

nums1=[1, 2, 3, 0, 0, 0]
m=3
nums2=[2, 5, 6]
n=3

s = Solution()
s.merge(nums1, m, nums2, n)
# Out:
# Merged nums1: [1, 2, 2, 3, 5, 6]

# %%
class Solution:
    def 1(self, nums1, m, nums2, n):
        """
        :type nums1: List[int]
        :type m: int
        :type nums2: List[int]
        :type n: int
        :rtype: None Do not return anything, modify nums1 in-place instead.
        """
        '''mine correct but not accepted'''
        num = []
        for i in range(len(nums1)):
            if nums1[i] != 0:
                # print(num1[i])
                num.append(nums1[i])
        nums1=num
        # nums1 +=nums2
        nums1.extend(nums2)
        nums1.sort()
        print(nums1)

# ----------------------------

    def merge2(nums1, m, nums2, n):
        nums1[:] = nums1[:m]  # Remove extra zeros at the end of nums1
        i, j = 0, 0
        while i < m and j < n:
            if nums1[i] <= nums2[j]:
                i += 1
            else:
                nums1.insert(i, nums2[j])
                j += 1
                m += 1
        if j < n:
            nums1.extend(nums2[j:])

        '''fastest time'''
    def merge3(self, nums1, m, nums2, n):
        """
        :type nums1: List[int]
        :type m: int
        :type nums2: List[int]
        :type n: int
        :rtype: None Do not return anything, modify nums1 in-place instead.
        """
        for j in range(n):
            nums1[m+j] = nums2[j]
        nums1.sort()
