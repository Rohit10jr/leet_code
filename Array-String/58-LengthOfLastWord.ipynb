# %% [markdown]
# "58. Length of Last Word"
#
# Given a string s consisting of words and spaces, return the length of the last word in the string.
#
# A word is a maximal substring consisting of non-space characters only.
#
#
# Example 1:
#
# Input: s = "Hello World"
# Output: 5
# Explanation: The last word is "World" with length 5.

# %%
import re
class Solution(object):
    def lengthOfLastWord(self, s):
        """
        :type s: str
        :rtype: int
        """

        '''best'''
        s = s.strip()  # Remove leading and trailing spaces
        return len(s.split()[-1])

        '''similar and simple, Looping Backwards'''
        # end = len(s) - 1
        # # Skip trailing spaces
        # while end >= 0 and s[end] == ' ':
        #     end -= 1
        
        # # Count the length of the last word
        # length = 0
        # while end >= 0 and s[end] != ' ':
        #     length += 1
        #     end -= 1
        
        # return length
    
        '''Using rstrip and rfind'''
        # s = s.rstrip()  # Remove trailing spaces
        # last_space_index = s.rfind(' ')  # Find the index of the last space
        # if last_space_index == -1:
        #     return len(s)  # No spaces, returns the length of entire string
        # else:
        #     return len(s) - last_space_index - 1  # Returns length of the last word
        
        '''Using Regular Expression'''
        # match = re.search(r'\b\w+\b(?!.*\b\w+\b)', s.strip())# Find last word using regex
        # return len(match.group()) if match else 0 #Returns length of last word


s = Solution()
print(s.lengthOfLastWord("hello world"))
# Out:
# 5

# %%
s = "hello world   "
print(len(s))
w = s.strip()  # Remove leading and trailing spaces
print(len(w))
print(w.split())
print(len(w.split()[-1]))
# Out:
# 15
# 12
# ['hello', 'worlds']
# 6
